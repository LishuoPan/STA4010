# %%
# import some basic package
# %matplotlib inline
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
# read the csv file in to dataframe. Read four days
df1 = pd.read_csv("./data/Day1.csv",header = 0,sep = ',')
df2 = pd.read_csv("./data/Day2.csv",header = 0,sep = ',')
df3 = pd.read_csv("./data/Day3.csv",header = 0,sep = ',')
df4 = pd.read_csv("./data/Day4.csv",header = 0,sep = ',')

# %%
## structurelize the data for further usage (matrixlize the data & data completion);
# n: dataset size; d: dimension
Data1 = df1.values
Data2 = df2.values
Data3 = df3.values
Data4 = df4.values
Data = np.vstack((Data1,Data2,Data3,Data4))
# get rid of first line: the time
Data = np.delete(Data, 0, axis=1)
n = Data.shape[0]
d = Data.shape[1]

# complete the dataset:
# principle: in the next line, if there is a nan, 
# keep the value same as the last line within same column
for i in range(n):
    for j in range(d):
        if math.isnan(Data[i,j]):
            Data[i,j] = Data[i-1,j]

# %%
# n: dataset size; d: dimension
# Out:
# [[77.4 5200.0 77.45 36800.0]
#  [77.4 6800.0 77.45 36800.0]
#  [77.4 13600.0 77.45 36800.0]
#  ...
#  [76.0 108800.0 76.05 100400.0]
#  [76.0 108800.0 76.05 91200.0]
#  [76.0 108800.0 76.05 91200.0]] 45164

# %%
# This module print the Bid & Ask price, Bid & Ask size
time = np.linspace(0,n,n)
BidP = Data[:,0]
Askp = Data[:,2]
Bidsize = Data[:,1]
Asksize = Data[:,3]
plt.plot(time,BidP,label='Bid price')
plt.plot(time,Askp,label='Ask price')
plt.legend()
plt.show()
plt.plot(time,Bidsize,label='Bid size')
plt.plot(time,Asksize,label='Ask size')
plt.legend()
plt.show()

# %% [markdown]
# # Notice there is a dramatic drop in the plot. The following code is to detact if this dramatic drop is due to some market operations rather than the real stock price fluctuation.

# %%
# Find the dramatic drop
big_drop = np.where(BidP < 76.5)[0][0]
print(big_drop)
print(BidP[big_drop-4:big_drop+5])
# Out:
# 31450
# [76.75 76.75 76.75 76.75 76.2 76.2 76.2 76.15 76.2]
